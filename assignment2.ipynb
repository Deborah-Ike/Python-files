# %%
# Initialize Otter
import otter
grader = otter.Notebook("assignment2.ipynb")

# %% [markdown]
# # STK353 Assignemnt 1
#
# ## Instructions:
#
#    - Complete all questions
#    - remember to restart your kernel and run all cells before submitting.
#    - Submit only the `ipynb` file | No need to rename it.
#    - Your data folder should be in a folder called data next to your script.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# **Question 1 (a)**: Read Total profit of all months and show it using a line plot
# Total profit data provided for each month. Generated line plot must include the following properties:
#
# - X label name = Month Number
# - Y label name = Total profit
# The line plot graph should look like this.
#
# ![](img/line.png)
#
# <!--
# BEGIN QUESTION
# manual: true
# name: q1a
# -->

# %%
df = pd.read_csv("data/company_sales_data.csv")
profit_list = df['total_profit'].tolist()
month_list = df['month_number'].tolist()
fig, ax = plt.subplots()
ax.plot(month_list, profit_list)
ax.set(xticks=month_list,
       yticks=[100000, 200000, 300000, 400000, 500000],
       xlabel='Month Number', 
       ylabel='Total profit', 
       title='Company Profit per Month')
plt.show()

# %% [markdown]
# <!-- END QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# **Question 1 (b)**: Read all product sales data and show it  using a multiline plot
# Display the number of units sold per month for each product using multiline plots. (i.e., Separate Plotline for each product).
#
# The graph should look like this:
#
# ![](img/lines.png)
#
#
# <!--
# BEGIN QUESTION
# manual: true
# name: q1b
# -->

# %%
month_list = df['month_number'].tolist()
face_cream_sales_data = df['facecream'].tolist()
face_wash_sales_data = df['facewash'].tolist()
tooth_paste_sales_data = df['toothpaste'].tolist()
bathing_soap_sales_data = df['bathingsoap'].tolist()
shampoo_sales_data = df['shampoo'].tolist()
moisturizer_sales_data = df['moisturizer'].tolist()

fig, ax = plt.subplots()

ax.plot(month_list, face_cream_sales_data, '-o', label='Face Cream Sales Data')
ax.plot(month_list, face_wash_sales_data, '-o', label='Face Wash Sales Data')
ax.plot(month_list, tooth_paste_sales_data, '-o', label='Tooth Paste Sales Data')
ax.plot(month_list, bathing_soap_sales_data, '-o', label='Bathing Soap Sales Data')
ax.plot(month_list, shampoo_sales_data, '-o', label='Shampoo Sales Data')
ax.plot(month_list, moisturizer_sales_data, '-o', label='Moisturizer Sales Data')

ax.set(xticks=month_list,
       yticks=[1000, 2000, 4000, 6000, 8000, 10000, 12000, 15000, 18000],
       xlabel='Month number', 
       ylabel='Sales unit in number', 
       title='Sales Data')

ax.legend(loc='upper left')

plt.show()

# %% [markdown]
# <!-- END QUESTION -->
#
# Import the `chipotle.tsv` and work out the following questions.
#
# **Question 2 (a):** Select only the products with quantity equals to 1 and assign this new dataframe to `chipo_one_prod`
#
#
# <!--
# BEGIN QUESTION
# name: q2_a
# points: 2
# -->

# %%
chipo = pd.read_csv('data/chipotle.tsv', sep = '\t')

chipo_one_prod = chipo[chipo["quantity"]==1]
chipo_one_prod
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 5            3         1                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
grader.check("q2_a")
# Out:
# q2_a results: All test cases passed!

# %% [markdown]
# **Question 2 (b):** Delete the duplicates in item_name and quantity and re-assign this new dataframe back to `chipo_filtered`
#
# <!--
# BEGIN QUESTION
# name: q2b
# points: 3
# -->

# %%
chipo_filtered = chipo.drop_duplicates(["item_name", "quantity"])

# %%
grader.check("q2b")
# Out:
# q2b results: All test cases passed!

# %% [markdown]
# **Question 3:** Create a DataFrame mirroring the table below and assign this to `data`. Then group by the `flavor` column and find the mean price for each flavor; assign this **series** to `price_by_flavor`.
#
# | flavor | scoops | price |
# |-----|-----|-----|
# | chocolate | 1 | 2 |
# | vanilla | 1 | 1.5 |
# | chocolate | 2 | 3 |
# | strawberry | 1 | 2 |
# | strawberry | 3 | 4 |
# | vanilla | 2 | 2 |
# | mint | 1 | 4 |
# | mint | 2 | 5 |
# | chocolate | 3 | 5 |
#
#
#
# <!--
# BEGIN QUESTION
# name: q3
# points:
#     each: 1
# -->

# %%
data = pd.DataFrame({'flavor':['chocolate','vanilla','chocolate','strawberry','strawberry','vanilla','mint','mint','chocolate'],
       'scoops':[1,1,2,1,3,2,1,2,3],
       'price':[2,1.5,3,2,4,2,4,5,5]})
data
price_by_flavor = data.groupby(['flavor'])['price'].mean()
price_by_flavor
# Out:
# flavor
# chocolate     3.333333
# mint          4.500000
# strawberry    3.000000
# vanilla       1.750000
# Name: price, dtype: float64

# %%
grader.check("q3")
# Out:
# q3 results: All test cases passed!

# %% [markdown]
# **Question 4**: Import the `drinks.csv` dataset and answer the following questions

# %%
drinks = pd.read_csv('data/drinks.csv')
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %% [markdown]
# **Question 4 (a):** Compute the mean beer servings per continent ? [type: pd.Series]
#
#
# <!--
# BEGIN QUESTION
# name: q4a
# points: 2
# -->

# %%
q4a = drinks.groupby(['continent'])['beer_servings'].mean()

# %%
grader.check("q4a")
# Out:
# q4a results: All test cases passed!

# %% [markdown]
# **Question 4 (b):** Calculate the mean alcohol consumption per continent for every columnm  [type: pd.DataFrame]
#
# <!--
# BEGIN QUESTION
# name: q4b
# points: 4
# -->

# %%
q4b = drinks.groupby('continent').mean()

# %%
grader.check("q4b")
# Out:
# q4b results: All test cases passed!

# %% [markdown]
# ---
#
# To double-check your work, the cell below will rerun all of the autograder tests.

# %%
grader.check_all()
# Out:
# q1 results:
#     q1 - 1 result:
#         Trying:
#             isinstance(x, float)
#         Expecting:
#             True
#         **********************************************************************
#         Line 1, in q1 0
#         Failed example:
#             isinstance(x, float)
#         Exception raised:
#             Traceback (most recent call last):
#               File "C:\Users\ikeoy\Anaconda3\lib\doctest.py", line 1329, in __run
#                 compileflags, 1), test.globs)
#               File "<doctest q1 0[0]>", line 1, in <module>
#                 isinstance(x, float)
#             NameError: name 'x' is not defined
#
#     q1 - 2 result:
#         Trying:
#             isinstance(y, int)
#         Expecting:
#             True
#         **********************************************************************
#         Line 1, in q1 1
#         Failed example:
#             isinstance(y, int)
#         Exception raised:
# ...
